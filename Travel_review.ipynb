# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d=pd.read_csv('/content/drive/MyDrive/tripadvisor_review.csv')

# %%
x=d['Category 3']
y=d['Category 1']
plt.plot(x,y,'r')

# %%
x=d['Category 2']
y=d['Category 1']
plt.plot(x,y,'r')

# %%
x=d['Category 4']
y=d['Category 1']
plt.plot(x,y,'r','b')

# %%
x=d['Category 5']
y=d['Category 1']
plt.plot(x,y,'r')

# %%
x=d['Category 3']
y=d['Category 2']
plt.plot(x,y,'r')

# %%
x=d['Category 4']
y=d['Category 2']
plt.plot(x,y,'r')

# %%
x=d['Category 5']
y=d['Category 2']
plt.plot(x,y,'r')

# %%
x=d['Category 4']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 5']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 6']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 7']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 8']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 3']
plt.plot(x,y,'r')

# %%
x=d['Category 5']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 6']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 7']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 8']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 4']
plt.plot(x,y,'r')

# %%
x=d['Category 6']
y=d['Category 5']
plt.plot(x,y,'r')

# %%
x=d['Category 7']
y=d['Category 5']
plt.plot(x,y,'r')

# %%
x=d['Category 8']
y=d['Category 5']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 5']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 5']
plt.plot(x,y,'r')

# %%
x=d['Category 7']
y=d['Category 6']
plt.plot(x,y,'r')

# %%
x=d['Category 8']
y=d['Category 6']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 6']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 6']
plt.plot(x,y,'r')

# %%
x=d['Category 8']
y=d['Category 7']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 7']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 7']
plt.plot(x,y,'r')

# %%
x=d['Category 9']
y=d['Category 8']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 8']
plt.plot(x,y,'r')

# %%
x=d['Category 10']
y=d['Category 9']
plt.plot(x,y,'r')
